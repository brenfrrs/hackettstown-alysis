# %%
import pandas as pd

# %%
data = pd.read_csv('/Volumes/ML_projects/richpeoplecars/NAD_r5_TXT/TXT/NAD_r5.csv', nrows=50000, skiprows=10000000)
# Out:
# /Users/brendanferris/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#        -1  NJ  BURLINGTON   MOORESTOWN TOWNSHIP  Unnamed: 4  Unnamed: 5  \
# 0      -1  NJ  BURLINGTON   MOORESTOWN TOWNSHIP         NaN         NaN
# 1      -1  NJ  BURLINGTON   MOORESTOWN TOWNSHIP         NaN         NaN
# 2      -1  NJ  BURLINGTON   MOORESTOWN TOWNSHIP         NaN         NaN
# 3      -1  NJ  BURLINGTON   MOORESTOWN TOWNSHIP         NaN         NaN
# 4      -1  NJ  BURLINGTON    LUMBERTON TOWNSHIP         NaN         NaN
# ...    ..  ..         ...                   ...         ...         ...
# 49995  -1  NJ  BURLINGTON   BURLINGTON TOWNSHIP         NaN         NaN
# 49996  -1  NJ  BURLINGTON  CINNAMINSON TOWNSHIP         NaN         NaN
# 49997  -1  NJ  BURLINGTON   BURLINGTON TOWNSHIP         NaN         NaN
# 49998  -1  NJ  BURLINGTON   BURLINGTON TOWNSHIP         NaN         NaN
# 49999  -1  NJ  BURLINGTON   BURLINGTON TOWNSHIP         NaN         NaN
#
#         MOORESTOWN   08057    3970  Unnamed: 9  ...  18SWK0931327363  \
# 0       MOORESTOWN  8057.0  2126.0         NaN  ...  18SWK0553226260
# 1              NaN  8057.0     NaN         NaN  ...  18SWK0234823240
# 2       MOORESTOWN  8057.0  2361.0         NaN  ...  18SWK0380923329
# 3       MOORESTOWN  8057.0  2636.0         NaN  ...  18SWK0355322186
# 4        LUMBERTON  8048.0  5235.0         NaN  ...  18SWK1333322552
# ...            ...     ...     ...         ...  ...              ...
# 49995   BURLINGTON  8016.0  4282.0         NaN  ...  18TWK1567633777
# 49996  CINNAMINSON  8077.0  3354.0         NaN  ...  18SWK0011926969
# 49997   BURLINGTON  8016.0  2269.0         NaN  ...  18TWK1043133347
# 49998   BURLINGTON  8016.0  4712.0         NaN  ...  18TWK1308433540
# 49999   BURLINGTON  8016.0  4709.0         NaN  ...  18TWK1324633706
#
#        {D9E664A9-0CE6-4E2D-BF68-85C33051F214}  Unknown               SITE  \
# 0      {F9409DA6-3CEE-4B3F-BEE2-0D6CACB4E649}  Unknown               SITE
# 1      {66586603-A2B5-4075-A9E3-F88F980179C4}  Unknown               SITE
# 2      {F7B19D16-92F0-4420-B391-8BD326EDFE34}  Unknown               SITE
# 3      {5F6CCC25-EB7B-40E2-B3EF-14D2DF0A32A5}  Unknown               SITE
# 4      {AE8443D7-8825-47C8-9449-E2F6C2B1B830}  Unknown               SITE
# ...                                       ...      ...                ...
# 49995  {69AD2D2A-5501-4746-AC64-3C03D6D30EB1}  Unknown  PARCEL - CENTROID
# 49996  {03B2D025-6A09-47AB-BA21-F18BA8FC4512}  Unknown  PARCEL - CENTROID
# 49997  {FFDE283F-AE26-4B99-AC20-4B10114CD4E9}  Unknown  PARCEL - CENTROID
# 49998  {34B640F8-9315-42EE-ADD6-9484D31BB026}  Unknown  PARCEL - CENTROID
# 49999  {7F1F6FED-DCD7-4F62-B2B0-2AE94167681C}  Unknown  PARCEL - CENTROID
#
#        NEW JERSEY OFFICE OF GIS  NJ OFFICE OF GIS Unnamed: 38  \
# 0      NEW JERSEY OFFICE OF GIS  NJ OFFICE OF GIS         NaN
# 1      NEW JERSEY OFFICE OF GIS  NJ OFFICE OF GIS         NaN
# 2      NEW JERSEY OFFICE OF GIS  NJ OFFICE OF GIS         NaN
# 3      NEW JERSEY OFFICE OF GIS  NJ OFFICE OF GIS         NaN
# 4      NEW JERSEY OFFICE OF GIS  NJ OFFICE OF GIS         NaN
# ...                         ...               ...         ...
# 49995  NEW JERSEY OFFICE OF GIS  NJ OFFICE OF GIS         NaN
# 49996  NEW JERSEY OFFICE OF GIS  NJ OFFICE OF GIS         NaN
# 49997  NEW JERSEY OFFICE OF GIS  NJ OFFICE OF GIS         NaN
# 49998  NEW JERSEY OFFICE OF GIS  NJ OFFICE OF GIS         NaN
# 49999  NEW JERSEY OFFICE OF GIS  NJ OFFICE OF GIS         NaN
#
#        4/15/2016 0:00:00 Unnamed: 40  Unnamed: 41
# 0      4/15/2016 0:00:00         NaN          NaN
# 1      4/15/2016 0:00:00         NaN          NaN
# 2      4/15/2016 0:00:00         NaN          NaN
# 3      4/15/2016 0:00:00         NaN          NaN
# 4      4/15/2016 0:00:00         NaN          NaN
# ...                  ...         ...          ...
# 49995  4/15/2016 0:00:00         NaN          NaN
# 49996  4/15/2016 0:00:00         NaN          NaN
# 49997  4/15/2016 0:00:00         NaN          NaN
# 49998  4/15/2016 0:00:00         NaN          NaN
# 49999  4/15/2016 0:00:00         NaN          NaN
#
# [50000 rows x 42 columns]

# %%
col = "OID,State,County,Inc_Muni,Uninc_Comm,Nbrhd_Comm,Post_Comm,Zip_Code,Plus_4,Bulk_Zip,Bulk_Plus4,StN_PreMod,StN_PreDir,StN_PreTyp,StN_PreSep,StreetName,StN_PosTyp,StN_PosDir,StN_PosMod,AddNum_Pre,Add_Number,AddNum_Suf,LandmkPart,LandmkName,Building,Floor,Unit,Room,Addtl_Loc,Milepost,Longitude,Latitude,NatGrid_Coord,GUID,Addr_Type,Placement,Source,AddAuth,UniqWithin,LastUpdate,Effective,Expired"
str_col = col.split(',')
data.columns = str_col

# %%
subset = data[['State', 'Post_Comm', 'StreetName', 'StN_PosDir', 'Add_Number', 'StN_PosTyp', 'Unit', 'Zip_Code']]

# %%
subset.fillna('NULL', inplace=True)
# Out:
# /Users/brendanferris/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:4259: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs

# %%
subset = subset.loc[subset['Post_Comm'] != 'NULL']

# %%
subset.to_csv('south_jersey.csv', index=False)

# %%
subset.tail(50)
# Out:
#       State     Post_Comm    StreetName StN_PosDir  Add_Number StN_PosTyp  \
# 49950    NJ    BURLINGTON       LIBERTE       NULL        1233      COURT
# 49951    NJ    BURLINGTON          KAYE       NULL        1178      COURT
# 49952    NJ    BORDENTOWN  BIRCH HOLLOW       NULL         267      DRIVE
# 49953    NJ    BORDENTOWN  BIRCH HOLLOW       NULL         351      DRIVE
# 49954    NJ   WILLINGBORO       NIAGARA       NULL          35       LANE
# 49995    NJ    BURLINGTON      LINDSLEY       NULL         708      COURT
# 49996    NJ   CINNAMINSON     WESTFIELD       NULL         712      DRIVE
# 49997    NJ    BURLINGTON          KAYE       NULL        1128      COURT
# 49998    NJ    BURLINGTON        GARNET       NULL         508      DRIVE
# 49999    NJ    BURLINGTON        GARNET       NULL         202      DRIVE
#
#       Floor      Unit  Room Zip_Code
# 49950  NULL      NULL  NULL     8016
# 49951  NULL      NULL  NULL     8016
# 49952  NULL      NULL  NULL     8505
# 49953  NULL      NULL  NULL     8505
# 49954  NULL      NULL  NULL     8046
# 49955  NULL      NULL  NULL     8046
# 49956  NULL      NULL  NULL     8505
# 49957  NULL      NULL  NULL     8016
# 49958  NULL      NULL  NULL     8016
# 49959  NULL      NULL  NULL     8515
# 49960  NULL      NULL  NULL     8016
# 49961  NULL      NULL  NULL     8016
# 49962  NULL      NULL  NULL     8016
# 49963  NULL      NULL  NULL     8016
# 49964  NULL      NULL  NULL     8016
# 49965  NULL      NULL  NULL     8016
# 49966  NULL      NULL  NULL     8016
# 49967  NULL      NULL  NULL     8016
# 49968  NULL      NULL  NULL     8016
# 49969  NULL      NULL  NULL     8016
# 49970  NULL      NULL  NULL     8016
# 49971  NULL      NULL  NULL     8016
# 49972  NULL      NULL  NULL     8016
# 49973  NULL      NULL  NULL     8053
# 49974  NULL      NULL  NULL     8016
# 49975  NULL      NULL  NULL     8016
# 49976  NULL      NULL  NULL     8016
# 49977  NULL      NULL  NULL     8016
# 49978  NULL      NULL  NULL     8016
# 49979  NULL      NULL  NULL     8016
# 49980  NULL      NULL  NULL     8016
# 49981  NULL   UNIT 1B  NULL     8016
# 49982  NULL   UNIT 2A  NULL     8016
# 49983  NULL   UNIT 7G  NULL     8016
# 49984  NULL   UNIT 6A  NULL     8016
# 49985  NULL      NULL  NULL     8016
# 49986  NULL      NULL  NULL     8505
# 49987  NULL      NULL  NULL     8048
# 49988  NULL      NULL  NULL     8016
# 49989  NULL      NULL  NULL     8016
# 49990  NULL      NULL  NULL     8016
# 49991  NULL      NULL  NULL     8016
# 49992  NULL  UNIT 10O  NULL     8016
# 49993  NULL      NULL  NULL     8016
# 49994  NULL      NULL  NULL     8016
# 49995  NULL      NULL  NULL     8016
# 49996  NULL      NULL  NULL     8077
# 49997  NULL      NULL  NULL     8016
# 49998  NULL   UNIT 5I  NULL     8016
# 49999  NULL   UNIT 2K  NULL     8016

# %%
subset['Unit'] = subset['Unit'].str.replace('UNIT', '')
# Out:
# /Users/brendanferris/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
subset.loc[subset['Room'] != 'NULL']
# Out:
# Empty DataFrame
# Columns: [State, Post_Comm, StreetName, StN_PosDir, Add_Number, StN_PosTyp, Floor, Unit, Room, Zip_Code]
# Index: []
